# %%
import pandas as pd
import numpy as np

# %%
local_file_path = ".data/blob/main/Booli_sold.csv"
url = "https://raw.githubusercontent.com/su-mt4007/data/refs/heads/main/Booli_sold.csv"
df = pd.read_csv(url)

# %%
#new dataset with relevant data for this homework
clean_data = df[["soldPrice","livingArea","location.address.streetAddress"]]
clean_data
# Out:
#      soldPrice  livingArea location.address.streetAddress
# 0      3820000        73.0                 Åminnevägen 19
# 1      2355000        36.0                 Docentbacken 9
# 2      6110000        81.0                  Ekhagsvägen 5
# 3      8050000       107.0                Torphagsvägen 4
# 4      2400000        29.0               Torphagsvägen 14
# ..         ...         ...                            ...
# 153    1475000        26.0                 Ekhagsvägen 12
# 154    2245000        50.0                 Ekhagsvägen 12
# 155    1450000        23.0                 Åminnevägen 17
# 156    2200000        56.0               Torphagsvägen 18
# 157    2180000        50.0                 Ekhagsvägen 12
#
# [158 rows x 3 columns]

# %%
#Calculation of ppsqm
ppsqm = clean_data["soldPrice"]/clean_data["livingArea"]

# %%
# table of the relevant data with ppsqm as a new column
df["ppsqm"] = ppsqm
new_data = df[["soldPrice","livingArea","location.address.streetAddress","ppsqm"]]

# %%
#sorting data so that the most expensive appartments are displayed in a descending order
sorted_data = new_data.sort_values("soldPrice", ascending = False).head(20)
sorted_data.head(5)
# Out:
#     soldPrice  livingArea location.address.streetAddress         ppsqm
# 59    9250000       152.0               Torphagsvägen 22  60855.263158
# 5     8950000       125.0                Torphagsvägen 4  71600.000000
# 3     8050000       107.0                Torphagsvägen 4  75233.644860
# 40    7700000       114.0               Torphagsvägen 14  67543.859649
# 32    7500000        97.0                  Ekhagsvägen 9  77319.587629

# %%
# Filtering data for area ekhagen
ekhagen_data = new_data[new_data["location.address.streetAddress"].str.startswith("Ekhagsvägen")]
ekhagen_data.head(10)
# Out:
#     soldPrice  livingArea location.address.streetAddress         ppsqm
# 2     6110000        81.0                  Ekhagsvägen 5  75432.098765
# 10    2420000        29.0                  Ekhagsvägen 9  83448.275862
# 11    3260000        47.0                 Ekhagsvägen 12  69361.702128
# 14    6000000        97.0                  Ekhagsvägen 9  61855.670103
# 15    2750000        44.0                 Ekhagsvägen 12  62500.000000
# 18    4060000        71.0                 Ekhagsvägen 12  57183.098592
# 22    3450000        59.0                  Ekhagsvägen 4  58474.576271
# 23    2600000        39.0                  Ekhagsvägen 4  66666.666667
# 25    2610000        37.0                  Ekhagsvägen 8  70540.540541
# 28    4500000        76.0                  Ekhagsvägen 8  59210.526316

# %%
# Calculating the average ppsqm in Ekhagen
avg_ppsqm = ekhagen_data["ppsqm"].mean()
print(avg_ppsqm)
# Out:
# 54841.59105899805

# %% [markdown]
#  An interesting observation from the data worth highlighting is that the appartments on Torphagsvägen seems to be the most expensive ones.

# %%
local_file_path = ".data/blob/main/2018_R_per_kommun.csv"
url = "https://raw.githubusercontent.com/su-mt4007/data/refs/heads/main/2018_R_per_kommun.csv"
datafile = pd.read_csv(url, engine = 'python',sep = r';',decimal = ',')
datafile
# Out:
#      LÄNSKOD  KOMMUNKOD         LÄNSNAMN      KOMMUNNAMN      M      C     L  \
# 0          1         14   Stockholms län  Upplands Väsby  23.11   6.26  5.66
# 1          1         15   Stockholms län      Vallentuna  28.29  10.11  7.73
# 2          1         17   Stockholms län       Österåker  29.68   9.35  7.48
# 3          1         20   Stockholms län          Värmdö  27.49   9.76  6.40
# 4          1         23   Stockholms län        Järfälla  23.96   6.31  6.04
# ..       ...        ...              ...             ...    ...    ...   ...
# 285       25         80  Norrbottens län           Luleå  15.38   7.53  4.37
# 286       25         81  Norrbottens län           Piteå  11.82   7.49  2.52
# 287       25         82  Norrbottens län           Boden  14.32   6.23  3.61
# 288       25         83  Norrbottens län       Haparanda  12.79   9.61  1.86
# 289       25         84  Norrbottens län          Kiruna  10.71   5.38  2.51
#
#        KD      S      V  ...  TRP  VL-S   ÖVR  OGEJ  BLANK    OG  \
# 0    6.71  26.97   8.01  ...  NaN   NaN   NaN  0.04   0.69  0.06
# 1    7.58  18.91   4.47  ...  0.0   NaN  0.00  0.02   0.59  0.08
# 2    7.13  19.71   4.97  ...  NaN   NaN  0.01  0.03   0.69  0.13
# 3    5.89  20.48   6.02  ...  NaN   NaN  0.01  0.04   0.67  0.07
# 4    6.29  27.68   8.75  ...  0.0   NaN  0.02  0.04   0.53  0.07
# ..    ...    ...    ...  ...  ...   ...   ...   ...    ...   ...
# 285  4.78  38.97  10.47  ...  NaN   NaN  0.01  0.03   0.69  0.04
# 286  4.80  47.48  10.56  ...  NaN   NaN  0.00  0.03   0.61  0.02
# 287  4.61  41.76   8.10  ...  NaN   NaN  0.02  0.03   0.84  0.07
# 288  5.32  36.69   5.91  ...  NaN   NaN   NaN  0.04   1.01  0.11
# 289  4.91  38.23  13.46  ...  NaN  0.05  0.02  0.16   1.09  0.05
#
#      RÖSTER GILTIGA  RÖSTANDE  RÖSTBERÄTTIGADE  VALDELTAGANDE
# 0             25830     26036            30740          84.70
# 1             20952     21099            23438          90.02
# 2             27711     27947            31309          89.26
# 3             28115     28335            31371          90.32
# 4             45654     45948            53230          86.32
# ..              ...       ...              ...            ...
# 285           53182     53589            60185          89.04
# 286           29523     29719            33094          89.80
# 287           19110     19291            21934          87.95
# 288            4402      4454             6120          72.78
# 289           14796     14991            17468          85.82
#
# [290 rows x 45 columns]

# %%
# Data for stockholms län
filtered_data = datafile[datafile["LÄNSNAMN"]  == "Stockholms län"]
filtered_data
# Out:
#     LÄNSKOD  KOMMUNKOD        LÄNSNAMN      KOMMUNNAMN      M      C      L  \
# 0         1         14  Stockholms län  Upplands Väsby  23.11   6.26   5.66
# 1         1         15  Stockholms län      Vallentuna  28.29  10.11   7.73
# 2         1         17  Stockholms län       Österåker  29.68   9.35   7.48
# 3         1         20  Stockholms län          Värmdö  27.49   9.76   6.40
# 4         1         23  Stockholms län        Järfälla  23.96   6.31   6.04
# 5         1         25  Stockholms län           Ekerö  28.12  11.24   7.64
# 6         1         26  Stockholms län        Huddinge  24.07   7.52   6.14
# 7         1         27  Stockholms län        Botkyrka  18.52   5.19   4.39
# 8         1         28  Stockholms län           Salem  24.84   7.61   7.58
# 9         1         36  Stockholms län         Haninge  22.94   6.06   5.11
# 10        1         38  Stockholms län          Tyresö  25.84   7.93   6.94
# 11        1         39  Stockholms län    Upplands-Bro  23.16   6.01   5.43
# 12        1         40  Stockholms län         Nykvarn  27.24   7.65   4.56
# 13        1         60  Stockholms län            Täby  35.97  10.98  10.71
# 14        1         62  Stockholms län        Danderyd  41.59  11.28  11.19
# 15        1         63  Stockholms län      Sollentuna  28.07  10.18   8.97
# 16        1         80  Stockholms län       Stockholm  21.88   9.07   7.85
# 17        1         81  Stockholms län      Södertälje  19.81   5.86   4.45
# 18        1         82  Stockholms län           Nacka  28.73  12.18   8.41
# 19        1         83  Stockholms län      Sundbyberg  22.37   8.05   7.06
# 20        1         84  Stockholms län           Solna  23.71   9.03   8.12
# 21        1         86  Stockholms län         Lidingö  36.02  11.79  10.78
# 22        1         87  Stockholms län         Vaxholm  30.31  13.30   7.76
# 23        1         88  Stockholms län       Norrtälje  22.23   9.60   4.74
# 24        1         91  Stockholms län         Sigtuna  24.66   6.65   4.93
# 25        1         92  Stockholms län       Nynäshamn  21.05   6.44   4.49
#
#        KD      S      V  ...  TRP  VL-S   ÖVR  OGEJ  BLANK    OG  \
# 0    6.71  26.97   8.01  ...  NaN   NaN   NaN  0.04   0.69  0.06
# 1    7.58  18.91   4.47  ...  0.0   NaN  0.00  0.02   0.59  0.08
# 2    7.13  19.71   4.97  ...  NaN   NaN  0.01  0.03   0.69  0.13
# 3    5.89  20.48   6.02  ...  NaN   NaN  0.01  0.04   0.67  0.07
# 4    6.29  27.68   8.75  ...  0.0   NaN  0.02  0.04   0.53  0.07
# 5    7.85  17.17   4.76  ...  NaN   NaN  0.01  0.01   0.64  0.08
# 6    5.35  26.10   8.63  ...  NaN   NaN  0.01  0.04   0.58  0.07
# 7    8.13  32.34   9.85  ...  NaN   NaN  0.06  0.03   0.64  0.05
# 8    7.98  23.07   5.98  ...  NaN   NaN   NaN  0.04   0.75  0.02
# 9    5.36  27.29   7.99  ...  0.0   NaN  0.01  0.05   0.79  0.05
# 10   5.75  23.87   6.37  ...  NaN   NaN  0.00  0.03   0.64  0.06
# 11   7.54  26.16   6.65  ...  NaN   NaN  0.01  0.04   0.75  0.05
# 12   6.06  22.42   3.52  ...  NaN   NaN   NaN   NaN   0.93  0.07
# 13   8.31  13.99   3.20  ...  NaN   NaN  0.01  0.01   0.44  0.04
# 14  10.10   8.04   2.36  ...  NaN   NaN   NaN  0.03   0.24  0.03
# 15   7.53  20.85   6.49  ...  NaN   NaN  0.01  0.03   0.50  0.06
# 16   4.87  23.76  13.12  ...  NaN   NaN  0.01  0.04   0.49  0.06
# 17  11.17  27.18   7.70  ...  NaN   NaN  0.00  0.03   0.76  0.06
# 18   6.10  19.37   6.54  ...  NaN   NaN  0.00  0.03   0.49  0.04
# 19   5.03  26.60  11.04  ...  NaN   NaN  0.01  0.03   0.59  0.05
# 20   5.80  24.00   9.89  ...  NaN   NaN  0.00  0.03   0.46  0.06
# 21   8.59  12.35   3.50  ...  NaN   NaN   NaN  0.01   0.28  0.04
# 22   7.90  16.37   4.70  ...  NaN   NaN  0.01  0.04   0.48  0.06
# 23   5.92  26.24   6.21  ...  NaN   NaN  0.00  0.02   1.09  0.02
# 24   7.56  25.49   6.39  ...  NaN   NaN  0.02  0.04   0.68  0.04
# 25   5.82  27.28   6.76  ...  NaN   NaN   NaN  0.05   0.85  0.07
#
#     RÖSTER GILTIGA  RÖSTANDE  RÖSTBERÄTTIGADE  VALDELTAGANDE
# 0            25830     26036            30740          84.70
# 1            20952     21099            23438          90.02
# 2            27711     27947            31309          89.26
# 3            28115     28335            31371          90.32
# 4            45654     45948            53230          86.32
# 5            17814     17946            19472          92.16
# 6            61440     61869            72839          84.94
# 7            45393     45719            58436          78.24
# 8             9985     10066            11463          87.81
# 9            50484     50940            59890          85.06
# 10           30260     30482            33776          90.25
# 11           16366     16506            19023          86.77
# 12            6847      6916             7623          90.73
# 13           46386     46616            51157          91.12
# 14           21897     21961            23891          91.92
# 15           43676     43934            49597          88.58
# 16          611206    614860           704157          87.32
# 17           48273     48684            62783          77.54
# 18           64101     64465            71629          90.00
# 19           29807     30009            35047          85.63
# 20           50510     50788            58093          87.43
# 21           31032     31138            34536          90.16
# 22            8106      8153             8791          92.74
# 23           41174     41643            47811          87.10
# 24           25576     25772            31071          82.95
# 25           17642     17815            20606          86.46
#
# [26 rows x 45 columns]

# %%
# Calculation of giltliga röster
giltliga_röster = filtered_data["RÖSTER GILTIGA"].sum()
print(giltliga_röster)
# Out:
# 1426237

# %%
#Sorted data for Socialdemokraterna with decending order of voting percentage
clean_data = datafile[["LÄNSNAMN","KOMMUNNAMN","S"]]
sorted_data = clean_data.sort_values("S", ascending = False)
sorted_data
# Out:
#             LÄNSNAMN  KOMMUNNAMN      S
# 188    Värmlands län    Munkfors  52.18
# 286  Norrbottens län       Piteå  47.48
# 196    Värmlands län     Hagfors  47.46
# 279  Norrbottens län   Överkalix  46.68
# 280  Norrbottens län       Kalix  45.37
# ..               ...         ...    ...
# 133     Hallands län  Kungsbacka  16.32
# 13    Stockholms län        Täby  13.99
# 21    Stockholms län     Lidingö  12.35
# 98         Skåne län    Vellinge  10.58
# 14    Stockholms län    Danderyd   8.04
#
# [290 rows x 3 columns]

# %% [markdown]
# Munkfors is the answer

# %%
# Sorting all data with descending order of participation in municipialities
partic_sorted_data = datafile.sort_values("VALDELTAGANDE", ascending = False)
partic_sorted_data[["KOMMUNNAMN", "VALDELTAGANDE"]].head(3)
# Out:
#     KOMMUNNAMN  VALDELTAGANDE
# 103      Lomma          93.86
# 59        Habo          93.35
# 98    Vellinge          93.13

# %% [markdown]
# The answer is Lomma, Habo and Vellinge

# %%
import numpy as np
import matplotlib.pyplot as plt
local_file_path = ".data/blob/main/stroke-data.csv"
url = "https://raw.githubusercontent.com/su-mt4007/data/refs/heads/main/stroke-data.csv"
df = pd.read_csv(url)
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
# Sorting the data into groups of male and female data and plotting the number of strokes for each group
male_data = df[df["gender"]=="Male"]
female_data = df[df["gender"]=="Female"]
strokes_male = male_data["stroke"].sum()
strokes_female=female_data["stroke"].sum()
xdata = ["Male","Female"]
ydata = [strokes_male,strokes_female]
plt.bar(xdata, ydata, color ='blue', 
        width = 0.4)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# The barplot indicates that strokes are somewhat more common for females given the data.
